# %% [markdown]
# # Yellow Taxi Data Analysis for Whole 2009 Year

# %%
import polars as pl

# %% [markdown]
# ## Step 1: Load Lazy Mode Through Polars Scan

# %%
path = r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2009\yellow_taxi\*.parquet"
yellow_2009 = pl.scan_parquet(path)

# %% [markdown]
# ## Step 2: Features Engineering

# %%
yellow_2009 = (
    yellow_2009.with_columns([
                    (pl.col("fare_amount") + pl.col("tips_amount")).alias("total_amount"),
                    (pl.col("duration") / 60).round(2).alias("duration_min"),
                     pl.when(pl.col("distance") > 10)
                     .then(pl.lit(1))
                     .otherwise(pl.lit(0))
                     .alias("long_trip_flag")
                      ])
               .filter(pl.col("fare_amount") > 0)  # remove bad rows
               .select(["distance", "duration_min", "total_amount", "long_trip_flag", "target"])
)
