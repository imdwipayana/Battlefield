# %%
import polars as pl

# %%
data_2009 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2009\yellow_taxi\yellow_tripdata_2009-01.parquet')
data_2009.head(2)
# Out:
# shape: (2, 18)
# ┌────────────┬────────────┬────────────┬───────────┬───┬─────────┬─────────┬───────────┬───────────┐
# │ vendor_nam ┆ Trip_Picku ┆ Trip_Dropo ┆ Passenger ┆ … ┆ mta_tax ┆ Tip_Amt ┆ Tolls_Amt ┆ Total_Amt │
# │ e          ┆ p_DateTime ┆ ff_DateTim ┆ _Count    ┆   ┆ ---     ┆ ---     ┆ ---       ┆ ---       │
# │ ---        ┆ ---        ┆ e          ┆ ---       ┆   ┆ f64     ┆ f64     ┆ f64       ┆ f64       │
# │ str        ┆ str        ┆ ---        ┆ i64       ┆   ┆         ┆         ┆           ┆           │
# │            ┆            ┆ str        ┆           ┆   ┆         ┆         ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═════════╪═════════╪═══════════╪═══════════╡
# │ VTS        ┆ 2009-01-04 ┆ 2009-01-04 ┆ 1         ┆ … ┆ null    ┆ 0.0     ┆ 0.0       ┆ 9.4       │
# │            ┆ 02:52:00   ┆ 03:02:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ VTS        ┆ 2009-01-04 ┆ 2009-01-04 ┆ 3         ┆ … ┆ null    ┆ 2.0     ┆ 0.0       ┆ 14.6      │
# │            ┆ 03:31:00   ┆ 03:38:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴─────────┴─────────┴───────────┴───────────┘

# %%
data_2010 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2010\yellow_taxi\yellow_tripdata_2010-01.parquet')
data_2010.head(2)
# Out:
# shape: (2, 18)
# ┌───────────┬────────────┬───────────┬───────────┬───┬─────────┬───────────┬───────────┬───────────┐
# │ vendor_id ┆ pickup_dat ┆ dropoff_d ┆ passenger ┆ … ┆ mta_tax ┆ tip_amoun ┆ tolls_amo ┆ total_amo │
# │ ---       ┆ etime      ┆ atetime   ┆ _count    ┆   ┆ ---     ┆ t         ┆ unt       ┆ unt       │
# │ str       ┆ ---        ┆ ---       ┆ ---       ┆   ┆ f64     ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str        ┆ str       ┆ i64       ┆   ┆         ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪════════════╪═══════════╪═══════════╪═══╪═════════╪═══════════╪═══════════╪═══════════╡
# │ VTS       ┆ 2010-01-26 ┆ 2010-01-2 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 5.0       │
# │           ┆ 07:41:00   ┆ 6         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 07:45:00  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ DDS       ┆ 2010-01-30 ┆ 2010-01-3 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 16.3      │
# │           ┆ 23:31:00   ┆ 0         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 23:46:12  ┆           ┆   ┆         ┆           ┆           ┆           │
# └───────────┴────────────┴───────────┴───────────┴───┴─────────┴───────────┴───────────┴───────────┘

# %%
data_2011 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2011\yellow_taxi\yellow_tripdata_2011-01.parquet')
data_2011.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2011-01-0 ┆ 2011-01-0 ┆ 4         ┆ … ┆ 0.0       ┆ 4.18      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:10:00  ┆ 00:12:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2011-01-0 ┆ 2011-01-0 ┆ 4         ┆ … ┆ 0.0       ┆ 6.94      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:04:00  ┆ 00:13:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2011['airport_fee'].value_counts()
# Out:
# shape: (2, 2)
# ┌─────────────┬──────────┐
# │ airport_fee ┆ count    │
# │ ---         ┆ ---      │
# │ f64         ┆ u32      │
# ╞═════════════╪══════════╡
# │ 0.0         ┆ 1        │
# │ null        ┆ 13464996 │
# └─────────────┴──────────┘

# %%
data_2012 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2012\yellow_taxi\yellow_tripdata_2012-01.parquet')
data_2012.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ null      ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2012-01-0 ┆ 2012-01-0 ┆ 1         ┆ … ┆ 0.0       ┆ 5.9       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:07:56  ┆ 00:12:09  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2012-01-0 ┆ 2012-01-0 ┆ 1         ┆ … ┆ 0.0       ┆ 9.5       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:18:49  ┆ 00:30:01  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2012["airport_fee"].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬──────────┐
# │ airport_fee ┆ count    │
# │ ---         ┆ ---      │
# │ null        ┆ u32      │
# ╞═════════════╪══════════╡
# │ null        ┆ 13058348 │
# └─────────────┴──────────┘

# %%
data_2013 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2013\yellow_taxi\yellow_tripdata_2013-01.parquet')
data_2013.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ null      ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2013-01-0 ┆ 2013-01-0 ┆ 3         ┆ … ┆ 0.0       ┆ 16.0      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:39:00  ┆ 00:55:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2013-01-0 ┆ 2013-01-0 ┆ 5         ┆ … ┆ 0.0       ┆ 4.62      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:00  ┆ 00:16:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2013['airport_fee'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬──────────┐
# │ airport_fee ┆ count    │
# │ ---         ┆ ---      │
# │ null        ┆ u32      │
# ╞═════════════╪══════════╡
# │ null        ┆ 14776617 │
# └─────────────┴──────────┘

# %%
data_2014 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2014\yellow_taxi\yellow_tripdata_2014-01.parquet')
data_2014.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2014-01-0 ┆ 2014-01-0 ┆ 6         ┆ … ┆ 0.0       ┆ 4.52      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:02:00  ┆ 00:04:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2014-01-0 ┆ 2014-01-0 ┆ 5         ┆ … ┆ 0.0       ┆ 4.55      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:06:00  ┆ 00:09:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2014['airport_fee'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬──────────┐
# │ airport_fee ┆ count    │
# │ ---         ┆ ---      │
# │ null        ┆ u32      │
# ╞═════════════╪══════════╡
# │ null        ┆ 13782517 │
# └─────────────┴──────────┘

# %%
data_2015 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2015\yellow_taxi\yellow_tripdata_2015-01.parquet')
data_2015.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ null      ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2015-01-0 ┆ 2015-01-0 ┆ 1         ┆ … ┆ 0.0       ┆ 8.4       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:11:33  ┆ 00:16:48  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2015-01-0 ┆ 2015-01-0 ┆ 1         ┆ … ┆ 0.0       ┆ 7.3       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:18:24  ┆ 00:24:20  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2015['airport_fee'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬──────────┐
# │ airport_fee ┆ count    │
# │ ---         ┆ ---      │
# │ null        ┆ u32      │
# ╞═════════════╪══════════╡
# │ null        ┆ 12741035 │
# └─────────────┴──────────┘

# %%
data_2016 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2016\yellow_taxi\yellow_tripdata_2016-01.parquet')
data_2016.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ null      ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2016-01-0 ┆ 2016-01-0 ┆ 1         ┆ … ┆ 0.3       ┆ 18.36     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:22  ┆ 00:29:14  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2016-01-0 ┆ 2016-01-0 ┆ 2         ┆ … ┆ 0.3       ┆ 10.8      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:41:31  ┆ 00:55:10  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2016['airport_fee'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬──────────┐
# │ airport_fee ┆ count    │
# │ ---         ┆ ---      │
# │ null        ┆ u32      │
# ╞═════════════╪══════════╡
# │ null        ┆ 10905067 │
# └─────────────┴──────────┘

# %%
data_2017 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2017\yellow_taxi\yellow_tripdata_2017-01.parquet')
data_2017.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ null      ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2017-01-0 ┆ 2017-01-0 ┆ 1         ┆ … ┆ 0.3       ┆ 7.8       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:32:05  ┆ 00:37:48  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2017-01-0 ┆ 2017-01-0 ┆ 2         ┆ … ┆ 0.3       ┆ 6.3       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:43:25  ┆ 00:47:42  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2017['airport_fee'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬─────────┐
# │ airport_fee ┆ count   │
# │ ---         ┆ ---     │
# │ null        ┆ u32     │
# ╞═════════════╪═════════╡
# │ null        ┆ 9710820 │
# └─────────────┴─────────┘

# %%
data_2018 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2018\yellow_taxi\yellow_tripdata_2018-01.parquet')
data_2018.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2018-01-0 ┆ 2018-01-0 ┆ 1         ┆ … ┆ 0.3       ┆ 5.8       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:21:05  ┆ 00:24:23  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2018-01-0 ┆ 2018-01-0 ┆ 1         ┆ … ┆ 0.3       ┆ 15.3      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:44:55  ┆ 01:03:05  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2018['airport_fee'].value_counts()
# Out:
# shape: (2, 2)
# ┌─────────────┬─────────┐
# │ airport_fee ┆ count   │
# │ ---         ┆ ---     │
# │ f64         ┆ u32     │
# ╞═════════════╪═════════╡
# │ 0.0         ┆ 12      │
# │ null        ┆ 8760675 │
# └─────────────┴─────────┘

# %%
# 2019 must convert csv to parquet
# C:\Users\ekadw\Documents\DATA\NY_Taxi\2019\yellow_taxi
data_2019 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2019\yellow_taxi\yellow_tripdata_2019-01.parquet')
data_2019.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data_2019 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2019\yellow_taxi\yellow_tripdata_2019-01.parquet')
#       2 data_2019.head(2)
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\polars\io\parquet\functions.py:289, in read_parquet(source, columns, n_rows, row_index_name, row_index_offset, parallel, use_statistics, hive_partitioning, glob, schema, hive_schema, try_parse_hive_dates, rechunk, low_memory, storage_options, credential_provider, retries, use_pyarrow, pyarrow_options, memory_map, include_file_paths, missing_columns, allow_missing_columns)
#     286     else:
#     287         lf = lf.select(columns)
# --> 289 return lf.collect()
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\polars\lazyframe\opt_flags.py:330, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     329 kwargs["optimizations"] = optflags
# --> 330 return function(*args, **kwargs)
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\polars\lazyframe\frame.py:2335, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2333 # Only for testing purposes
#    2334 callback = _kwargs.get("post_opt_callback", callback)
# -> 2335 return wrap_df(ldf.collect(engine, callback))
#
# FileNotFoundError: The system cannot find the file specified. (os error 2): C:\Users\ekadw\Documents\DATA\NY_Taxi\2019\yellow_taxi\yellow_tripdata_2019-01.parquet
#
# This error occurred with the following context stack:
# 	[1] 'parquet scan'
# 	[2] 'sink'

# %%
data_2019['airport_fee'].value_counts()

# %%
data_2020 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2020\yellow_taxi\yellow_tripdata_2020-01.parquet')
data_2020.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ null      │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2020-01-0 ┆ 2020-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 11.27     ┆ 2.5       ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:28:15  ┆ 00:33:03  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2020-01-0 ┆ 2020-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 12.3      ┆ 2.5       ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:35:39  ┆ 00:43:04  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2020['airport_fee'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────────────┬─────────┐
# │ airport_fee ┆ count   │
# │ ---         ┆ ---     │
# │ null        ┆ u32     │
# ╞═════════════╪═════════╡
# │ null        ┆ 6405008 │
# └─────────────┴─────────┘

# %%
data_2021 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2021\yellow_taxi\yellow_tripdata_2021-01.parquet')
data_2021.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2021-01-0 ┆ 2021-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 11.8      ┆ 2.5       ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:10  ┆ 00:36:12  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2021-01-0 ┆ 2021-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 4.3       ┆ 0.0       ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:51:20  ┆ 00:52:19  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2021['airport_fee'].value_counts()
# Out:
# shape: (2, 2)
# ┌─────────────┬─────────┐
# │ airport_fee ┆ count   │
# │ ---         ┆ ---     │
# │ f64         ┆ u32     │
# ╞═════════════╪═════════╡
# │ null        ┆ 1369764 │
# │ 0.0         ┆ 5       │
# └─────────────┴─────────┘

# %%
data_2022 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2022\yellow_taxi\yellow_tripdata_2022-01.parquet')
data_2022.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 2.0       ┆ … ┆ 0.3       ┆ 21.95     ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:35:40  ┆ 00:53:29  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 13.3      ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:33:43  ┆ 00:42:07  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2022['airport_fee'].value_counts()
# Out:
# shape: (4, 2)
# ┌─────────────┬─────────┐
# │ airport_fee ┆ count   │
# │ ---         ┆ ---     │
# │ f64         ┆ u32     │
# ╞═════════════╪═════════╡
# │ -1.25       ┆ 1051    │
# │ null        ┆ 71503   │
# │ 1.25        ┆ 158950  │
# │ 0.0         ┆ 2232427 │
# └─────────────┴─────────┘

# %%
data_2023 = pl.read_parquet(r'C:\Users\ekadw\Documents\DATA\NY_Taxi\2023\yellow_taxi\yellow_tripdata_2023-01.parquet')
data_2023.head(2)
# Out:
# shape: (2, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 1.0       ┆ … ┆ 1.0       ┆ 14.3      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:32:10  ┆ 00:40:36  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 1.0       ┆ … ┆ 1.0       ┆ 16.9      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:55:08  ┆ 01:01:27  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data_2023['airport_fee'].value_counts()
# Out:
# shape: (4, 2)
# ┌─────────────┬─────────┐
# │ airport_fee ┆ count   │
# │ ---         ┆ ---     │
# │ f64         ┆ u32     │
# ╞═════════════╪═════════╡
# │ null        ┆ 71743   │
# │ 0.0         ┆ 2730456 │
# │ 1.25        ┆ 260960  │
# │ -1.25       ┆ 3607    │
# └─────────────┴─────────┘
