# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\ekadw\Documents\DATA\Stock_Market\symbols_valid_meta.csv")
data.head()
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
data[data["Symbol"]=="PRN"]
# Out:
#      Nasdaq Traded Symbol                         Security Name  \
# 5738             Y    PRN  Invesco DWA Industrials Momentum ETF
#
#      Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 5738                Q               G   Y           100.0          N
#
#      Financial Status CQS Symbol NASDAQ Symbol NextShares
# 5738                N        NaN           PRN          N

# %%
len(data)
# Out:
# 8049

# %%
data_etfs = pd.read_csv(r"C:\Users\ekadw\Documents\DATA\Stock_Market\etfs\_PRN.csv")
data_etfs.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2006-10-12  25.459999  25.680000  25.459999  25.680000  23.301548   16300
# 1  2006-10-13  25.680000  25.680000  25.680000  25.680000  23.301548       0
# 2  2006-10-16  25.879999  26.379999  25.879999  26.379999  23.936714   12900
# 3  2006-10-17  26.150000  26.240000  26.090000  26.240000  23.809679    2400
# 4  2006-10-18  26.400000  26.400000  25.990000  25.990000  23.582838     700

# %%
len(data_etfs)
# Out:
# 3390

# %%
data_etfs.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 3385  2020-03-26  54.099998  56.790001  54.099998  56.720001  56.720001
# 3386  2020-03-27  54.360001  55.900002  54.360001  54.889999  54.889999
# 3387  2020-03-30  55.509998  56.529999  55.509998  56.529999  56.529999
# 3388  2020-03-31  55.759998  56.610001  55.490002  55.660000  55.660000
# 3389  2020-04-01  52.919998  53.259998  52.330002  52.430000  52.430000
#
#       Volume
# 3385    9100
# 3386    8400
# 3387   11700
# 3388    5400
# 3389    2900

# %%
data_stocks = pd.read_csv(r"C:\Users\ekadw\Documents\DATA\Stock_Market\stocks\AAON.csv")
data_stocks.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume
# 0  1992-12-16  0.099763  0.099763  0.099763  0.099763   0.084743    1900
# 1  1992-12-17  0.119716  0.129692  0.099763  0.119716   0.101691  163900
# 2  1992-12-18  0.119716  0.119716  0.119716  0.119716   0.101691   14100
# 3  1992-12-21  0.099763  0.099763  0.089787  0.099763   0.084743   32400
# 4  1992-12-22  0.099763  0.119716  0.099763  0.119716   0.101691   62100
