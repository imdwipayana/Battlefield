# %% [markdown]
# ## 1. Convert csv Files to Parquet Format

# %%
import os
import glob
import pandas as pd

# Root folder that contains subfolders of CSV files
root_dir = r"C:/Users/ekadw/Documents/DATA/Stock_Market/"

# Recursively find all CSV files
files = glob.glob(os.path.join(root_dir, "**", "*.csv"), recursive=True)

print(f"Found {len(files)} CSV files")

for f in files:
    try:
        # Read CSV
        df = pd.read_csv(f)
        
        # Build matching parquet path (same folder, same name, .parquet extension)
        parquet_path = os.path.splitext(f)[0] + ".parquet"
        
        # Save to Parquet
        df.to_parquet(parquet_path, index=False)
        
        #print(f"Converted: {f} -> {parquet_path}") # it is too long
    except Exception as e:
        print(f"Failed to convert {f}: {e}")
# Out:
# Found 8050 CSV files

# %% [markdown]
# ## 2. Use SQL query to produce the fDD dataframe the same as assignment 1

# %%
import duckdb
con = duckdb.connect()

stock_query = """
WITH CTE_filename AS (
    SELECT
        *,
        "Adj Close" AS Adj_Close,
        regexp_extract(filename, '([^/\\\\]+)\\.parquet$') AS source,
        regexp_extract(filename, '([^/\\\\]+)\\.parquet$', 1) AS ticker,
        EXTRACT(YEAR FROM CAST(Date AS DATE)) AS year,
        LAG(Close, 1) OVER (PARTITION BY ticker ORDER BY Date ASC) AS Close_Lag_1,
        LAG(Adj_Close,1) OVER (PARTITION BY ticker ORDER BY Date ASC) AS Adj_Close_Lag_1,
        High - Low AS hi_lo_range
    FROM read_parquet('C:/Users/ekadw/Documents/DATA/Stock_Market/*/*.parquet', filename=true)
), CTE_lag AS (
    SELECT
        *,
        (Close/Close_Lag_1) - 1 AS returns
    FROM CTE_filename
), CTE_returns AS (
    SELECT
        *,
        CASE 
            WHEN COUNT(returns) OVER (PARTITION BY ticker ORDER BY Date ROWS BETWEEN 9 PRECEDING AND CURRENT ROW) = 10
            THEN AVG(returns) OVER (PARTITION BY ticker ORDER BY Date ROWS BETWEEN 9 PRECEDING AND CURRENT ROW)
        END AS ma10_returns
    FROM CTE_lag
)

SELECT
    Date,
    Open,
    High,
    Low,
    Close,
    Adj_Close,
    Volume,
    source,
    ticker,
    year,
    Close_Lag_1,
    Adj_Close_Lag_1,
    returns,
    hi_lo_range,
    ma10_returns
FROM CTE_returns
"""
stock_market = con.execute(stock_query).fetchdf()
stock_market.head()
# Out:
#          Date       Open       High        Low      Close  Adj_Close  Volume  \
# 0  2000-10-26  10.330579  10.330579  10.330579  10.330579   5.073581    3900
# 1  2000-10-27  10.330579  10.330579  10.330579  10.330579   5.073581   11000
# 2  2000-10-30  10.330579  10.415956  10.159825  10.394611   5.105032   16500
# 3  2000-10-31  10.245202  10.245202  10.074449  10.159825   4.989721   13400
# 4  2000-11-01  10.159825  10.159825  10.159825  10.159825   4.989721       0
#
#          source ticker  year  Close_Lag_1  Adj_Close_Lag_1   returns  \
# 0  CTBI.parquet   CTBI  2000    10.373267         5.094546 -0.004115
# 1  CTBI.parquet   CTBI  2000    10.330579         5.073581  0.000000
# 2  CTBI.parquet   CTBI  2000    10.330579         5.073581  0.006198
# 3  CTBI.parquet   CTBI  2000    10.394611         5.105032 -0.022587
# 4  CTBI.parquet   CTBI  2000    10.159825         4.989721  0.000000
#
#    hi_lo_range  ma10_returns
# 0     0.000000     -0.000755
# ...

# %% [markdown]
# ## 3.Check the part of dataframe that shows the result is the same with assignment 1

# %%
fDD = stock_market[stock_market["ticker"]=='AAON'].sort_values(by="Date")
fDD.head(20)
# Out:
#                 Date      Open      High       Low     Close  Adj_Close  \
# 13928192  1992-12-16  0.099763  0.099763  0.099763  0.099763   0.084743
# 13928193  1992-12-17  0.119716  0.129692  0.099763  0.119716   0.101691
# 13928194  1992-12-18  0.119716  0.119716  0.119716  0.119716   0.101691
# 13928195  1992-12-21  0.099763  0.099763  0.089787  0.099763   0.084743
# 13928196  1992-12-22  0.099763  0.119716  0.099763  0.119716   0.101691
# 13928197  1992-12-23  0.099763  0.099763  0.099763  0.099763   0.084743
# 13928198  1992-12-24  0.129692  0.139668  0.129692  0.129692   0.110165
# 13928199  1992-12-28  0.129692  0.129692  0.129692  0.129692   0.110165
# 13928200  1992-12-29  0.129692  0.129692  0.129692  0.129692   0.110165
# 13928201  1992-12-30  0.129692  0.129692  0.129692  0.129692   0.110165
# 13928202  1992-12-31  0.139668  0.149645  0.139668  0.139668   0.118640
# 13928203  1993-01-04  0.139668  0.149645  0.129692  0.149645   0.127114
# ...

# %%
len(stock_market)
# Out:
# 28151758
