# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Config
N_CUSTOMERS = 5000
N_DAYS = 180

# Customer segments
segments = ["loyal", "average", "at_risk", "churn_prone"]
segment_probs = [0.20, 0.40, 0.25, 0.15]
segment_assignment = np.random.choice(segments, N_CUSTOMERS, p=segment_probs)

# Base purchase probabilities
segment_purchase_prob = {
    "loyal": 0.20,
    "average": 0.10,
    "at_risk": 0.05,
    "churn_prone": 0.02
}

# Marketing actions
ACTIONS = ["no_action", "email", "small_coupon", "big_coupon"]
action_effects = {
    "no_action": 0.00,
    "email": 0.03,
    "small_coupon": 0.07,
    "big_coupon": 0.15
}

rows = []

for cust_id in range(N_CUSTOMERS):
    seg = segment_assignment[cust_id]
    base_prob = segment_purchase_prob[seg]

    for day in range(N_DAYS):
        # choose an action (random for now)
        action = np.random.choice(ACTIONS)

        # probability of purchase today
        p = base_prob + action_effects[action]
        p = min(max(p, 0), 1)

        purchased = np.random.rand() < p
        amount = np.random.exponential(50) if purchased else 0

        rows.append({
            "customer_id": cust_id,
            "day": day,
            "segment": seg,
            "action": action,
            "purchase": int(purchased),
            "amount": amount
        })

df = pd.DataFrame(rows)
df.head()
# Out:
#    customer_id  day  segment        action  purchase     amount
# 0            0    0  average  small_coupon         0   0.000000
# 1            0    1  average    big_coupon         0   0.000000
# 2            0    2  average         email         0   0.000000
# 3            0    3  average     no_action         1  74.984002
# 4            0    4  average  small_coupon         0   0.000000

# %%
df.segment.value_counts()
# Out:
# segment
# average        354600
# at_risk        228780
# loyal          185220
# churn_prone    131400
# Name: count, dtype: int64

# %%
df.action.value_counts()
# Out:
# action
# big_coupon      225832
# no_action       225424
# small_coupon    224382
# email           224362
# Name: count, dtype: int64

# %%
df.purchase.value_counts()
# Out:
# purchase
# 0    756577
# 1    143423
# Name: count, dtype: int64

# %%
df.amount.value_counts().hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.amount.value_counts().hist()
#
# File ~\anaconda3\envs\ReinforcementLearning\Lib\site-packages\pandas\plotting\_core.py:128, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      47 def hist_series(
#      48     self: Series,
#      49     by=None,
#    (...)     60     **kwargs,
#      61 ):
#      62     """
#      63     Draw histogram of the input series using matplotlib.
#      64
#    (...)    126         >>> hist = ser.groupby(level=0).hist()
#     127     """
# --> 128     plot_backend = _get_plot_backend(backend)
#     129     return plot_backend.hist_series(
#     130         self,
#     131         by=by,
#    (...)    141         **kwargs,
#     142     )
#
# ...

# %%
        # !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp312-cp312-win_amd64.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.7-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.60.1-cp312-cp312-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# ...
#
# ...
