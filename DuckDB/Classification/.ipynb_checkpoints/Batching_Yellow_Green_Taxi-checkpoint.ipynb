# %%
import duckdb

# %%
query_yellow_green = """
WITH CTE_yellow_2009 AS (
    SELECT 
        CAST(Trip_Pickup_DateTime AS TIMESTAMP) AS pick_up_time,
        CAST(Trip_Dropoff_DateTime AS TIMESTAMP) AS drop_off_time,
        CAST(Passenger_Count AS INTEGER) AS passenger_count,
        CAST(Trip_Distance AS INTEGER) AS trip_distance,
        Payment_Type AS payment_type,
        CAST(Total_Amt AS FLOAT)   AS total_amount,
        Tip_Amt AS tip_amount,
        CAST(Tip_Amt AS FLOAT)   AS tip_amount,
        CAST( CASE Payment_Type
            WHEN  'Credit' THEN 1
            WHEN  'CREDIT' THEN 1
            ELSE 2
        END AS INTEGER) AS payment_category,
        CAST( CASE Tip_Amt
            WHEN  0.0 THEN 1
            ELSE 0
        END AS INTEGER) AS tip_category
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2009/yellow_taxi_2009/yellow_tripdata_*.parquet'
    WHERE Trip_Pickup_DateTime IS NOT NULL
        AND Trip_Dropoff_DateTime IS NOT NULL
        AND Passenger_Count >= 0
        AND Trip_Distance >= 0 
        AND Trip_Distance <= 50
        AND Payment_Type IS NOT NULL
        AND Total_Amt >= 0
        AND Tip_Amt >= 0
        AND Trip_Pickup_DateTime >= '2009-01-01' 
        AND Trip_Pickup_DateTime < '2010-01-01'
), CTE_duration_yellow_2009 AS (
    SELECT
        pick_up_time,
        drop_off_time,
        passenger_count,
        trip_distance,
        total_amount,
        payment_category,
        tip_category,
        DATE_DIFF('day', pick_up_time, drop_off_time) AS duration_days,
        EPOCH(drop_off_time - pick_up_time) AS duration_seconds
    FROM CTE_yellow_2009
    WHERE payment_category = 1
), CTE_yellow_2010 AS (
    SELECT 
        CAST(pickup_datetime AS TIMESTAMP) AS pick_up_time,
        CAST(dropoff_datetime AS TIMESTAMP) AS drop_off_time,
        CAST(passenger_count AS INTEGER) AS passenger_count,
        CAST(total_amount AS FLOAT)   AS total_amount,
        CAST(trip_distance AS FLOAT)   AS trip_distance,
        payment_type,
        tip_amount,
        CAST( CASE payment_type
            WHEN  'Cre' THEN 1
            WHEN  'CRE' THEN 1
            ELSE 2
        END AS INTEGER) AS payment_category,
        CAST( CASE tip_amount
            WHEN  0.0 THEN 1
            ELSE 0
        END AS INTEGER) AS tip_category
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2010/yellow_taxi_2010/yellow_tripdata_*.parquet'
    WHERE pickup_datetime IS NOT NULL
        AND dropoff_datetime  IS NOT NULL
        AND passenger_count >= 0
        AND trip_distance >= 0
        AND trip_distance <= 50
        AND payment_type IS NOT NULL
        AND total_amount >= 0
        AND tip_amount >= 0 
        AND pickup_datetime >= '2010-01-01' 
        AND pickup_datetime < '2011-01-01'
), CTE_duration_yellow_2010 AS (
    SELECT
        pick_up_time,
        drop_off_time,
        passenger_count,
        trip_distance,
        total_amount,
        payment_category,
        tip_category,
        DATE_DIFF('day', pick_up_time, drop_off_time) AS duration_days,
        EPOCH(drop_off_time - pick_up_time) AS duration_seconds
    FROM CTE_yellow_2010
    WHERE payment_category = 1
), CTE_yellow_2011_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        CAST(passenger_count AS INTEGER) AS passenger_count,
        CAST(total_amount AS FLOAT)   AS total_amount,
        CAST(trip_distance AS FLOAT)   AS trip_distance,
        CAST(payment_type AS INTEGER) AS payment_category,
        tip_amount,
        CAST( CASE tip_amount
            WHEN  0.0 THEN 1
            ELSE 0
        END AS INTEGER) AS tip_category
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/*/yellow_taxi/yellow_tripdata_*.parquet'
    WHERE tpep_pickup_datetime IS NOT NULL
        AND tpep_dropoff_datetime  IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance >= 0
        AND trip_distance <= 50
        AND payment_type IS NOT NULL
        AND total_amount >= 0
        AND tip_amount >= 0
        AND tpep_pickup_datetime >= '2011-01-01' 
        AND tpep_pickup_datetime < '2023-10-01'
), CTE_duration_yellow_2011_2023 AS (
    SELECT
        pick_up_time,
        drop_off_time,
        passenger_count,
        trip_distance,
        total_amount,
        payment_category,
        tip_category,
        DATE_DIFF('day', pick_up_time, drop_off_time) AS duration_days,
        EPOCH(drop_off_time - pick_up_time) AS duration_seconds
    FROM CTE_yellow_2011_2023
    WHERE payment_category = 1
), CTE_green_2011_2023 AS (
    SELECT 
        lpep_pickup_datetime AS pick_up_time,
        lpep_dropoff_datetime AS drop_off_time,
        CAST(passenger_count AS INTEGER) AS passenger_count,
        CAST(total_amount AS FLOAT)   AS total_amount,
        CAST(trip_distance AS FLOAT)   AS trip_distance,
        CAST(payment_type AS INTEGER) AS payment_category,
        tip_amount,
        CAST( CASE tip_amount
            WHEN  0.0 THEN 1
            ELSE 0
        END AS INTEGER) AS tip_category
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/*/green_taxi/green_tripdata_*.parquet'
    WHERE lpep_pickup_datetime IS NOT NULL
        AND lpep_dropoff_datetime  IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance >= 0
        AND trip_distance <= 50
        AND payment_type IS NOT NULL
        AND total_amount >= 0
        AND tip_amount >= 0
        AND lpep_pickup_datetime >= '2009-01-01' 
        AND lpep_pickup_datetime < '2023-10-01'
), CTE_duration_green_2011_2023 AS (
    SELECT
        pick_up_time,
        drop_off_time,
        passenger_count,
        trip_distance,
        total_amount,
        payment_category,
        tip_category,
        DATE_DIFF('day', pick_up_time, drop_off_time) AS duration_days,
        EPOCH(drop_off_time - pick_up_time) AS duration_seconds
    FROM CTE_green_2011_2023
    WHERE payment_category = 1
), CTE_union_all AS (
    SELECT * FROM CTE_duration_yellow_2009
    UNION ALL
    SELECT * FROM CTE_duration_yellow_2010
    UNION ALL
    SELECT * FROM CTE_duration_yellow_2011_2023
    UNION ALL
    SELECT * FROM CTE_duration_green_2011_2023
)

SELECT 
    passenger_count,
    trip_distance,
    total_amount,
    CAST(duration_seconds AS FLOAT)   AS duration_seconds,
    tip_category
FROM CTE_union_all
WHERE duration_days = 0
LIMIT 50000000
"""

con = duckdb.connect()
df_yellow_green = con.execute(query_yellow_green).fetchdf()
df_yellow_green.head()
# Out:
#    passenger_count  trip_distance  total_amount  duration_seconds  \
# 0                3            5.0     14.600000             420.0
# 1                5           10.0     28.440001             840.0
# 2                1            5.0     18.450001            1262.0
# 3                1            0.0      6.700000             585.0
# 4                1            2.0     10.000000             679.0
#
#    tip_category
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df_yellow_green.tip_category.value_counts()
# Out:
# tip_category
# 0    48520227
# 1     1479773
# Name: count, dtype: int64

# %%
percentages_tip_category = df_yellow_green["tip_category"].value_counts(normalize=True) * 100
print(percentages_tip_category)
# Out:
# tip_category
# 0    97.040454
# 1     2.959546
# Name: proportion, dtype: float64

# %%
import pandas as pd
from river import preprocessing, tree, metrics

# ----------------------------
# 1. Connect to DuckDB and run query
# ----------------------------
con = duckdb.connect("my_data.duckdb")
#query = "SELECT * FROM my_table"
res = con.execute(query_yellow_green)

# ----------------------------
# 2. Build pipeline (scaling + model)
# ----------------------------
pipeline = preprocessing.StandardScaler() | tree.HoeffdingTreeClassifier()
metric = metrics.F1()   # good for imbalanced classification

downsample_ratio = 3  # keep majority ~1:3 relative to minority

# ----------------------------
# 3. Streaming loop
# ----------------------------
while True:
    chunk = res.fetch_df_chunk(vectors_per_chunk=100000)
    if chunk is None or len(chunk) == 0:
        break

    # Split into minority and majority
    minority = chunk[chunk["tip_category"] == 1]
    majority = chunk[chunk["tip_category"] == 0]

    # Batch-wise downsampling
    if len(minority) > 0:
        majority_down = majority.sample(
            n=min(len(majority), downsample_ratio * len(minority)),
            random_state=42
        )
        batch_balanced = pd.concat([minority, majority_down], ignore_index=True)
    else:
        batch_balanced = chunk  # no minority in this chunk

    # Train incrementally
    for _, row in batch_balanced.iterrows():
        x = row.drop("tip_category").to_dict()
        y = row["tip_category"]

        # Predict before updating
        y_pred = pipeline.predict_one(x)

        # Update metric
        metric.update(y, y_pred)

        # Train (no reassignment!)
        pipeline.learn_one(x, y)

    print("Processed chunk, current F1:", metric.get())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 53
#      50     metric.update(y, y_pred)
#      52     # Train (no reassignment!)
# ---> 53     pipeline.learn_one(x, y)
#      55 print("Processed chunk, current F1:", metric.get())
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\compose\pipeline.py:474, in Pipeline.learn_one(self, x, y, **params)
#     471 # Here the step is not a transformer, and it's supervised, such as a LinearRegression.
#     472 # This is usually the last step of the pipeline.
#     473 elif step._supervised:
# --> 474     step.learn_one(x=x, y=y)
#     475 # Here the step is not a transformer, and it's unsupervised, such as a KMeans. This
#     476 # is also usually the last step of the pipeline.
#     477 else:
#     478     step.learn_one(x=x)
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\hoeffding_tree_classifier.py:365, in HoeffdingTreeClassifier.learn_one(self, x, y, w)
#     362     node = self._root
#     364 if isinstance(node, HTLeaf):
# --> 365     node.learn_one(x, y, w=w, tree=self)
#     366     if self._growth_allowed and node.is_active():
#     367         if node.depth >= self.max_depth:  # Max depth reached
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\nodes\htc_nodes.py:189, in LeafNaiveBayesAdaptive.learn_one(self, x, y, w, tree)
#     186 if len(self.stats) == 0 or max(mc_pred, key=mc_pred.get) == y:
#     187     self._mc_correct_weight += w
# --> 189 nb_pred = do_naive_bayes_prediction(x, self.stats, self.splitters)
#     190 if len(nb_pred) > 0 and max(nb_pred, key=nb_pred.get) == y:
#     191     self._nb_correct_weight += w
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\utils.py:57, in do_naive_bayes_prediction(x, observed_class_distribution, splitters)
#      55             obs = splitters[att_idx]
#      56             # Prior plus the log likelihood
# ---> 57             tmp = obs.cond_proba(x[att_idx], class_index)
#      58             votes[class_index] += math.log(tmp) if tmp > 0 else 0.0
#      60 # Max log-likelihood
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\splitter\gaussian_splitter.py:54, in GaussianSplitter.cond_proba(self, att_val, target_val)
#      52 if target_val in self._att_dist_per_class:
#      53     obs = self._att_dist_per_class[target_val]
# ---> 54     return obs(att_val)
#      55 else:
#      56     return 0.0
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\proba\gaussian.py:79, in Gaussian.__call__(self, x)
#      77 if var:
#      78     try:
# ---> 79         return math.exp((x - self.mu) ** 2 / (-2 * var)) / math.sqrt(math.tau * var)
#      80     except ValueError:
#      81         return 0.0
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\proba\gaussian.py:58, in Gaussian.mu(self)
#      54 @property
#      55 def n_samples(self):
#      56     return self._var.mean.n
# ---> 58 @property
#      59 def mu(self):
#      60     return self._var.mean.get()
#      62 @property
#      63 def sigma(self):
#
# KeyboardInterrupt:

# %%
import duckdb
import pandas as pd
from river import preprocessing, tree, metrics

# ----------------------------
# 1. Connect to DuckDB and query
# ----------------------------
con = duckdb.connect("my_data.duckdb")
#query = "SELECT * FROM my_table"
res = con.execute(query_yellow_green)

# ----------------------------
# 2. Build pipeline
# ----------------------------
pipeline = preprocessing.StandardScaler() | tree.HoeffdingTreeClassifier()

# Track multiple metrics
all_metrics = metrics.ClassificationReport(
    metrics.Accuracy(),
    metrics.Precision(),
    metrics.Recall(),
    metrics.F1(),
    metrics.ConfusionMatrix()
    # metrics.ROCAUC()  # only if model supports predict_proba_one
)

downsample_ratio = 3  # keep 1:3 balance

# ----------------------------
# 3. Streaming loop
# ----------------------------
while True:
    chunk = res.fetch_df_chunk(vectors_per_chunk=100_000)
    if chunk is None or len(chunk) == 0:
        break

    # Balance the batch
    minority = chunk[chunk["tip_category"] == 1]
    majority = chunk[chunk["tip_category"] == 0]

    if len(minority) > 0:
        majority_down = majority.sample(
            n=min(len(majority), downsample_ratio * len(minority)),
            random_state=42
        )
        batch_balanced = pd.concat([minority, majority_down], ignore_index=True)
    else:
        batch_balanced = chunk

    # Convert to dicts for speed
    records = batch_balanced.to_dict(orient="records")

    for r in records:
        x = {k: v for k, v in r.items() if k != "tip_category"}
        y = r["tip_category"]

        # Predict
        y_pred = pipeline.predict_one(x)

        # Update metrics
        all_metrics.update(y, y_pred)

        # Train
        pipeline.learn_one(x, y)

    # Print after each chunk
    print(all_metrics)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      15 pipeline = preprocessing.StandardScaler() | tree.HoeffdingTreeClassifier()
#      17 # Track multiple metrics
# ---> 18 all_metrics = metrics.ClassificationReport(
#      19     metrics.Accuracy(),
#      20     metrics.Precision(),
#      21     metrics.Recall(),
#      22     metrics.F1(),
#      23     metrics.ConfusionMatrix()
#      24     # metrics.ROCAUC()  # only if model supports predict_proba_one
#      25 )
#      27 downsample_ratio = 3  # keep 1:3 balance
#      29 # ----------------------------
#      30 # 3. Streaming loop
#      31 # ----------------------------
#
# TypeError: ClassificationReport.__init__() takes from 1 to 3 positional arguments but 6 were given
