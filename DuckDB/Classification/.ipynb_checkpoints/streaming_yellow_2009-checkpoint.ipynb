# %% [markdown]
# # New York Taxi Tiping Prediction: Yellow Taxi Dataset in 2009

# %%
import duckdb
import pandas as pd
from river import linear_model, preprocessing, metrics

# %%
query_yellow_2009 = """
WITH CTE_yellow_2009 AS (
    SELECT 
        CAST(Trip_Pickup_DateTime AS TIMESTAMP) AS pick_up_time,
        CAST(Trip_Dropoff_DateTime AS TIMESTAMP) AS drop_off_time,
        CAST(Passenger_Count AS INTEGER) AS passenger_count,
        CAST(Trip_Distance AS INTEGER) AS trip_distance,
        Payment_Type AS payment_type,
        CAST(Total_Amt AS FLOAT)   AS total_amount,
        Tip_Amt AS tip_amount,
        CAST(Tip_Amt AS FLOAT)   AS tip_amount,
        CAST( CASE Payment_Type
            WHEN  'Credit' THEN 1
            WHEN  'CREDIT' THEN 1
            ELSE 2
        END AS INTEGER) AS payment_category,
        CAST( CASE Tip_Amt
            WHEN  0.0 THEN 1
            ELSE 0
        END AS INTEGER) AS tip_category
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2009/yellow_taxi_2009/yellow_tripdata_*.parquet'
    WHERE Trip_Pickup_DateTime IS NOT NULL
        AND Trip_Dropoff_DateTime IS NOT NULL
        AND Passenger_Count >= 0
        AND Trip_Distance >= 0 
        AND Trip_Distance <= 50
        AND Payment_Type IS NOT NULL
        AND Total_Amt >= 0
        AND Tip_Amt >= 0
        AND Trip_Pickup_DateTime >= '2009-01-01' 
        AND Trip_Pickup_DateTime < '2010-01-01'
), CTE_duration_yellow_2009 AS (
    SELECT
        pick_up_time,
        drop_off_time,
        passenger_count,
        trip_distance,
        total_amount,
        payment_category,
        tip_category,
        DATE_DIFF('day', pick_up_time, drop_off_time) AS duration_days,
        EPOCH(drop_off_time - pick_up_time) AS duration_seconds
    FROM CTE_yellow_2009
    WHERE payment_category = 1
)

SELECT 
    passenger_count,
    trip_distance,
    total_amount,
    CAST(duration_seconds AS FLOAT)   AS duration_seconds,
    tip_category
FROM CTE_duration_yellow_2009
WHERE duration_days = 0
"""

#con = duckdb.connect()
#df_yellow_2009 = con.execute(query_yellow_2009).fetchdf()
#df_yellow_2009.head()

# %% [markdown]
# ## 1. Batching Dataset before Streaming
# Each batch will use 500000 rows.

# %%
# Connect to DuckDB
con = duckdb.connect("yellow_2009.duckdb")

# Example parameters
batch_size = 500_000
offset = 0

while True:
    df = con.execute(f"""
        {query_yellow_2009}
        LIMIT {batch_size} OFFSET {offset}
    """).fetchdf()

    if df.empty:
        break

    # process df here
    offset += batch_size

# %% [markdown]
# ## 2. Logistic Regression for Classification
# Use logistic regression as first try.

# %%
from river import linear_model, preprocessing, metrics

model = preprocessing.StandardScaler() | linear_model.LogisticRegression()
metric = metrics.Accuracy()

for batch in con.execute(query_yellow_2009).fetch_record_batch():
    df = batch.to_pandas()

    X = df.drop(columns=["tip_category"])
    y = df["tip_category"]

    for xi, yi in zip(X.to_dict(orient="records"), y):
        y_pred = model.predict_one(xi)
        model.learn_one(xi, yi)
        metric.update(yi, y_pred)

    print("Processed batch, accuracy:", metric.get())
# Out:
# Processed batch, accuracy: 0.969352
# Processed batch, accuracy: 0.969389
# Processed batch, accuracy: 0.9695183333333334
# Processed batch, accuracy: 0.9696045
# Processed batch, accuracy: 0.969676
# Processed batch, accuracy: 0.969718
# Processed batch, accuracy: 0.9696707142857143
# Processed batch, accuracy: 0.969594875
# Processed batch, accuracy: 0.9695737777777778
# Processed batch, accuracy: 0.9695547
# Processed batch, accuracy: 0.9695495454545454
# Processed batch, accuracy: 0.9695396666666667
# Processed batch, accuracy: 0.9695428461538461
# Processed batch, accuracy: 0.9695460714285714
# Processed batch, accuracy: 0.9695593333333333
# Processed batch, accuracy: 0.969560875
# Processed batch, accuracy: 0.9695795882352941
# Processed batch, accuracy: 0.9696272777777778
# Processed batch, accuracy: 0.9696817368421052
# Processed batch, accuracy: 0.9697211
# Processed batch, accuracy: 0.9697284761904762
# Processed batch, accuracy: 0.9697355
# Processed batch, accuracy: 0.9697342173913044
# Processed batch, accuracy: 0.96974225
# Processed batch, accuracy: 0.96973352
# Processed batch, accuracy: 0.9697362692307693
# Processed batch, accuracy: 0.9697285555555556
# Processed batch, accuracy: 0.9697314642857143
# Processed batch, accuracy: 0.969754275862069
# Processed batch, accuracy: 0.9697778
# Processed batch, accuracy: 0.969803
# Processed batch, accuracy: 0.9698290625
# Processed batch, accuracy: 0.9698600606060606
# Processed batch, accuracy: 0.9698939117647059
# Processed batch, accuracy: 0.9699315142857143
# Processed batch, accuracy: 0.9699626666666666
# Processed batch, accuracy: 0.9699716216216216
# Processed batch, accuracy: 0.9699800789473684
# Processed batch, accuracy: 0.9699802564102564
# Processed batch, accuracy: 0.96998475
# Processed batch, accuracy: 0.9699749512195122
# Processed batch, accuracy: 0.9699639047619047
# Processed batch, accuracy: 0.969947953488372
# Processed batch, accuracy: 0.9699357954545454
# Processed batch, accuracy: 0.969930091796053

# %% [markdown]
# ## 3. Balance Accuracy with Logistic Regression
# Since dataset highly imbalance, the accuracy metric is less accurate because model tend to predict the majority. For that reason, we can change the metric by focusing on balancing the imbalance dataset.

# %%
from river import linear_model, preprocessing, metrics

model = preprocessing.StandardScaler() | linear_model.LogisticRegression()
metric = metrics.BalancedAccuracy()   # better for imbalance

for batch in con.execute(query_yellow_2009).fetch_record_batch():
    df = batch.to_pandas()

    X = df.drop(columns=["tip_category"])
    y = df["tip_category"]

    for xi, yi in zip(X.to_dict(orient="records"), y):
        y_pred = model.predict_one(xi)
        model.learn_one(xi, yi)
        metric.update(yi, y_pred)

    print("Processed batch, balanced accuracy:", metric.get())
# Out:
# Processed batch, balanced accuracy: 0.5001508704244862
# Processed batch, balanced accuracy: 0.5001902493027736
# Processed batch, balanced accuracy: 0.5002146523773596
# Processed batch, balanced accuracy: 0.5001856682632837
# Processed batch, balanced accuracy: 0.5001685451341861
# Processed batch, balanced accuracy: 0.5001634486078645
# Processed batch, balanced accuracy: 0.5001777158014638
# Processed batch, balanced accuracy: 0.5001902210855368
# Processed batch, balanced accuracy: 0.5002270702429364
# Processed batch, balanced accuracy: 0.5002261360223541
# Processed batch, balanced accuracy: 0.5002170493212446
# Processed batch, balanced accuracy: 0.5002151275709655
# Processed batch, balanced accuracy: 0.5002024134647688
# Processed batch, balanced accuracy: 0.500209309617351
# Processed batch, balanced accuracy: 0.5002110089005969
# Processed batch, balanced accuracy: 0.5002076659266773
# Processed batch, balanced accuracy: 0.5002093394655317
# Processed batch, balanced accuracy: 0.5002035632429928
# Processed batch, balanced accuracy: 0.5002032035785793
# Processed batch, balanced accuracy: 0.5001975450605884
# Processed batch, balanced accuracy: 0.5001937235737576
# Processed batch, balanced accuracy: 0.5002005003877966
# Processed batch, balanced accuracy: 0.5002053793529103
# Processed batch, balanced accuracy: 0.5002009514978168
# Processed batch, balanced accuracy: 0.500199816536746
# Processed batch, balanced accuracy: 0.5001971398943686
# Processed batch, balanced accuracy: 0.5002016323239346
# Processed batch, balanced accuracy: 0.5002065447745628
# Processed batch, balanced accuracy: 0.5002090691701001
# Processed batch, balanced accuracy: 0.5002098238663428
# Processed batch, balanced accuracy: 0.5002083355225873
# Processed batch, balanced accuracy: 0.5002045710010191
# Processed batch, balanced accuracy: 0.5002049814299473
# Processed batch, balanced accuracy: 0.5002016721758763
# Processed batch, balanced accuracy: 0.5001986749465812
# Processed batch, balanced accuracy: 0.5001955635059141
# Processed batch, balanced accuracy: 0.5001915078709559
# Processed batch, balanced accuracy: 0.5001889125312795
# Processed batch, balanced accuracy: 0.5001842810152293
# Processed batch, balanced accuracy: 0.5001815533315993
# Processed batch, balanced accuracy: 0.500178687079563
# Processed batch, balanced accuracy: 0.5001744939675156
# Processed batch, balanced accuracy: 0.5001726924822247
# Processed batch, balanced accuracy: 0.5001703542840993
# Processed batch, balanced accuracy: 0.5001690901457418

# %% [markdown]
# ## 4. Tree Based Classifier for Imbalance Dataset
# Try the tree based model that representative for imbalance dataset.

# %%
from river import tree, preprocessing, metrics

model = preprocessing.StandardScaler() | tree.HoeffdingTreeClassifier(
    grace_period=200,
    delta=1e-5,       # instead of split_confidence
    tau=0.05,         # tie threshold
    max_depth=10
)

metric = metrics.BalancedAccuracy()

for batch in con.execute(query_yellow_2009).fetch_record_batch():
    df = batch.to_pandas()

    X = df.drop(columns=["tip_category"])
    y = df["tip_category"]

    for xi, yi in zip(X.to_dict(orient="records"), y):
        y_pred = model.predict_one(xi)
        model.learn_one(xi, yi)
        metric.update(yi, y_pred)

    print("Processed batch, balanced accuracy:", metric.get())
# Out:
# Processed batch, balanced accuracy: 0.3465653759666514
# Processed batch, balanced accuracy: 0.35102881393571456
# Processed batch, balanced accuracy: 0.3525940190289015
# Processed batch, balanced accuracy: 0.35383120108915106
# Processed batch, balanced accuracy: 0.35535007066747526
# Processed batch, balanced accuracy: 0.35601741556272076
# Processed batch, balanced accuracy: 0.35666285717798685
# Processed batch, balanced accuracy: 0.3563960058196987
# Processed batch, balanced accuracy: 0.3561883507748245
# Processed batch, balanced accuracy: 0.3564379135630134
# Processed batch, balanced accuracy: 0.3566742301948722
# Processed batch, balanced accuracy: 0.3565625308892881
# Processed batch, balanced accuracy: 0.35648590058547786
# Processed batch, balanced accuracy: 0.35656684376289016
# Processed batch, balanced accuracy: 0.35666791395482816
# Processed batch, balanced accuracy: 0.35676159768636423
# Processed batch, balanced accuracy: 0.3568688596347245
# Processed batch, balanced accuracy: 0.35687997248199066
# Processed batch, balanced accuracy: 0.357048812892095
# Processed batch, balanced accuracy: 0.3570376530095814
# Processed batch, balanced accuracy: 0.3568592412481362
# Processed batch, balanced accuracy: 0.35665364758872226
# Processed batch, balanced accuracy: 0.35651214328643466
# Processed batch, balanced accuracy: 0.3563420436023376
# Processed batch, balanced accuracy: 0.3561778699537665
# Processed batch, balanced accuracy: 0.3559358158854999
# Processed batch, balanced accuracy: 0.35562287560679046
# Processed batch, balanced accuracy: 0.35532288401653916
# Processed batch, balanced accuracy: 0.35498279811489675
# Processed batch, balanced accuracy: 0.35467309887461784
# Processed batch, balanced accuracy: 0.35439038356276814
# Processed batch, balanced accuracy: 0.35415270795892373
# Processed batch, balanced accuracy: 0.35389561296736005
# Processed batch, balanced accuracy: 0.3536449932185514
# Processed batch, balanced accuracy: 0.35345012524644237
# Processed batch, balanced accuracy: 0.3532356889703534
# Processed batch, balanced accuracy: 0.3528782555828213
# Processed batch, balanced accuracy: 0.35254616497868185
# Processed batch, balanced accuracy: 0.3522210493814155
# Processed batch, balanced accuracy: 0.35192512764701195
# Processed batch, balanced accuracy: 0.35164002544398576
# Processed batch, balanced accuracy: 0.3513713037424588
# Processed batch, balanced accuracy: 0.3511189332487697
# Processed batch, balanced accuracy: 0.35088798587486125
# Processed batch, balanced accuracy: 0.35079778741585566

# %% [markdown]
# Conclusion: the streaming process is succesfull. But the accuracy after balancing is around 0.5 (which is the same as random guessing). The tree based model has lower accuracy which is around 0.35 which is lower than random guessing. This will be the focus for next project, finding the accurate model that represent data properly.

# %%
from river import ensemble, metrics
from river.ensemble import ARFClassifier

# Adaptive Random Forest Classifier
model = ensemble.ARFClassifier(
    n_models=10,
    max_features='sqrt',
    lambda_value=6,
    seed=42
)

metric = metrics.BalancedAccuracy()

for batch in con.execute(query_yellow_2009).fetch_record_batch():
    df = batch.to_pandas()
    X = df.drop(columns=["tip_category"])
    y = df["tip_category"]

    for xi, yi in zip(X.to_dict(orient="records"), y):
        y_pred = model.predict_one(xi)
        model.learn_one(xi, yi)
        metric.update(yi, y_pred)

    print("Processed batch, balanced accuracy:", metric.get())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 from river import ensemble, metrics
# ----> 2 from river.ensemble import ARFClassifier
#       4 # Adaptive Random Forest Classifier
#       5 model = ensemble.ARFClassifier(
#       6     n_models=10,
#       7     max_features='sqrt',
#       8     lambda_value=6,
#       9     seed=42
#      10 )
#
# ImportError: cannot import name 'ARFClassifier' from 'river.ensemble' (C:\Users\ekadw\anaconda3\envs\SQLite\Lib\site-packages\river\ensemble\__init__.py)

# %%
from river import ensemble
print(dir(ensemble))
# Out:
# ['ADWINBaggingClassifier', 'ADWINBoostingClassifier', 'AdaBoostClassifier', 'BOLEClassifier', 'BaggingClassifier', 'BaggingRegressor', 'EWARegressor', 'LeveragingBaggingClassifier', 'SRPClassifier', 'SRPRegressor', 'StackingClassifier', 'VotingClassifier', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'annotations', 'bagging', 'boosting', 'ewa', 'stacking', 'streaming_random_patches', 'voting']

# %%
from river import ensemble, tree, metrics

# Leveraging Bagging for streaming imbalanced data
model = ensemble.LeveragingBaggingClassifier(
    model=tree.HoeffdingTreeClassifier(
        grace_period=50,
        delta=1e-7,
        max_depth=20
    ),
    n_models=10,
    w=6,       # Poisson resampling weight
    seed=42
)

metric = metrics.BalancedAccuracy()

for batch in con.execute(query_yellow_2009).fetch_record_batch():
    df = batch.to_pandas()
    X = df.drop(columns=["tip_category"])
    y = df["tip_category"]

    for xi, yi in zip(X.to_dict(orient="records"), y):
        y_pred = model.predict_one(xi)
        model.learn_one(xi, yi)
        metric.update(yi, y_pred)

    print("Processed batch, balanced accuracy:", metric.get())
# Out:
# Processed batch, balanced accuracy: 0.37349639222920267
# Processed batch, balanced accuracy: 0.38889684485763865
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 24
#      22 for xi, yi in zip(X.to_dict(orient="records"), y):
#      23     y_pred = model.predict_one(xi)
# ---> 24     model.learn_one(xi, yi)
#      25     metric.update(yi, y_pred)
#      27 print("Processed batch, balanced accuracy:", metric.get())
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\ensemble\bagging.py:386, in LeveragingBaggingClassifier.learn_one(self, x, y, **kwargs)
#     383 k = self._bagging_fct(x=x, y=y, model_idx=i)
#     385 for _ in range(k):
# --> 386     model.learn_one(x, y, **kwargs)
#     388 y_pred = self[i].predict_one(x)
#     389 if y_pred is not None:
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\hoeffding_tree_classifier.py:376, in HoeffdingTreeClassifier.learn_one(self, x, y, w)
#     374             if weight_diff >= self.grace_period:
#     375                 p_branch = p_node.branch_no(x) if isinstance(p_node, DTBranch) else None
# --> 376                 self._attempt_to_split(node, p_node, p_branch)
#     377                 node.last_split_attempt_at = weight_seen
#     378 else:
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\hoeffding_tree_classifier.py:316, in HoeffdingTreeClassifier._attempt_to_split(self, leaf, parent, parent_branch, **kwargs)
#     313         parent.children[parent_branch] = new_split
#     315 # Manage memory
# --> 316 self._enforce_size_limit()
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\hoeffding_tree.py:254, in HoeffdingTree._enforce_size_limit(self)
#     252         self._growth_allowed = False
#     253         return
# --> 254 leaves = self._find_leaves()
#     255 leaves.sort(key=lambda leaf: leaf.calculate_promise())
#     256 max_active = 0
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\hoeffding_tree.py:327, in HoeffdingTree._find_leaves(self)
#     320 def _find_leaves(self) -> list[HTLeaf]:
#     321     """Find learning nodes in the tree.
#     322
#     323     Returns
#     324     -------
#     325     List of learning nodes in the tree.
#     326     """
# --> 327     return [leaf for leaf in self._root.iter_leaves()]
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\base.py:118, in Branch.iter_leaves(self)
#     116 """Iterate over leaves from the left-most one to the right-most one."""
#     117 for child in self.children:
# --> 118     yield from child.iter_leaves()
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\base.py:118, in Branch.iter_leaves(self)
#     116 """Iterate over leaves from the left-most one to the right-most one."""
#     117 for child in self.children:
# --> 118     yield from child.iter_leaves()
#
#     [... skipping similar frames: Branch.iter_leaves at line 118 (17 times)]
#
# File ~\anaconda3\envs\SQLite\Lib\site-packages\river\tree\base.py:118, in Branch.iter_leaves(self)
#     116 """Iterate over leaves from the left-most one to the right-most one."""
#     117 for child in self.children:
# --> 118     yield from child.iter_leaves()
#
# KeyboardInterrupt:
