# %% [markdown]
# # Transform New York Taxi Dataset into Time Series Dataset
# There are four taxi types with different length time in New York City (2009-2023).
# 1. Yellow Taxi with data range from January 1st 2009 until September 30th 2023.
# 2. Green Taxi with data range from  January 1st 2014 until September 30th 2023.
# 3. For Hire Vehicle with data range from  January 1st 2015 until September 30th 2023.
# 4. High Volume For Hire Vehicle with data range from  January 1st 2019 until September 30th 2023.
#
# Each trip data was recorded and the daily data aggregation is required to create time series data for each type of taxi. There are 7 columns will be selected for data analysis, which are:
# 1. pick_up_time is the time passenger enter the taxi
# 2. drop_off_time is the time passenger get out from taxi
# 3. passenger_count is the number of passenger
# 4. trip_distance is the length of the trip
# 5. payment_type is the type of payment
# 6. total_amount is the total amount of charge for the trip
# 7. tip_amount is the amount of tips given by passenger
#
# With these columns data, the data pipeline is as follow:
# 1. Select those 7 columns from their original tables
# 2. Change their column name into stardard column name
# 3. Delete rows data that contain NULL
# 4. Filter data in the range of January 1st 2009 until September 30th 2023
#
# Then do aggregation for time series data
# 1. Find the number of daily/monthly trips for each taxi provider.
# 2. Find the average distance of each trip
# 3. Find the average of duration for each trip
# 4. Calculate percentage of tips compare to total amount paid

# %%
import polars as pl
import duckdb
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Yellow Taxi
# Unfortunately the name of column headers for yellow taxi are not the same. There will be a different in giving name title. For that reason, the column name must be standardized.

# %% [markdown]
# ### 1.1 The 2009 Yellow Taxi Data
# The column name will be changed as follow:
# 1. Trip_Pickup_DateTime is replaced by pick_up_time
# 2. Trip_Dropoff_DateTime is replaced by drop_off_time
# 3. Passenger_Count is replaced by passenger_count
# 4. Trip_Distance is replaced by trip_distance
# 5. Payment_Type is replaced by payment_type
# 6. Total_Amt is replaced by total_amount
# 7. Tip_Amt is replaced by tip_amount

# %%
#--- Read the 2009 Yellow Taxi dataset then look fer the first 5 rows ---
yellow_2009 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2009\yellow_taxi_2009\yellow_tripdata_2009-01.parquet")
yellow_2009.head()
# Out:
# shape: (5, 18)
# ┌────────────┬────────────┬────────────┬───────────┬───┬─────────┬─────────┬───────────┬───────────┐
# │ vendor_nam ┆ Trip_Picku ┆ Trip_Dropo ┆ Passenger ┆ … ┆ mta_tax ┆ Tip_Amt ┆ Tolls_Amt ┆ Total_Amt │
# │ e          ┆ p_DateTime ┆ ff_DateTim ┆ _Count    ┆   ┆ ---     ┆ ---     ┆ ---       ┆ ---       │
# │ ---        ┆ ---        ┆ e          ┆ ---       ┆   ┆ f64     ┆ f64     ┆ f64       ┆ f64       │
# │ str        ┆ str        ┆ ---        ┆ i64       ┆   ┆         ┆         ┆           ┆           │
# │            ┆            ┆ str        ┆           ┆   ┆         ┆         ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═════════╪═════════╪═══════════╪═══════════╡
# │ VTS        ┆ 2009-01-04 ┆ 2009-01-04 ┆ 1         ┆ … ┆ null    ┆ 0.0     ┆ 0.0       ┆ 9.4       │
# │            ┆ 02:52:00   ┆ 03:02:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ VTS        ┆ 2009-01-04 ┆ 2009-01-04 ┆ 3         ┆ … ┆ null    ┆ 2.0     ┆ 0.0       ┆ 14.6      │
# │            ┆ 03:31:00   ┆ 03:38:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ VTS        ┆ 2009-01-03 ┆ 2009-01-03 ┆ 5         ┆ … ┆ null    ┆ 4.74    ┆ 0.0       ┆ 28.44     │
# │            ┆ 15:43:00   ┆ 15:57:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ DDS        ┆ 2009-01-01 ┆ 2009-01-01 ┆ 1         ┆ … ┆ null    ┆ 3.05    ┆ 0.0       ┆ 18.45     │
# │            ┆ 20:52:58   ┆ 21:14:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ DDS        ┆ 2009-01-24 ┆ 2009-01-24 ┆ 1         ┆ … ┆ null    ┆ 0.0     ┆ 0.0       ┆ 3.7       │
# │            ┆ 16:18:23   ┆ 16:24:56   ┆           ┆   ┆         ┆         ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴─────────┴─────────┴───────────┴───────────┘

# %%
#--- Find out all the columns name ---
yellow_2009.columns
# Out:
# ['vendor_name',
#  'Trip_Pickup_DateTime',
#  'Trip_Dropoff_DateTime',
#  'Passenger_Count',
#  'Trip_Distance',
#  'Start_Lon',
#  'Start_Lat',
#  'Rate_Code',
#  'store_and_forward',
#  'End_Lon',
#  'End_Lat',
#  'Payment_Type',
#  'Fare_Amt',
#  'surcharge',
#  'mta_tax',
#  'Tip_Amt',
#  'Tolls_Amt',
#  'Total_Amt']

# %% [markdown]
# ### 1.2 The 2010 Yellow Taxi Data
# The column name will be changed as follow:
# 1. pickup_datetime is replaced by pick_up_time
# 2. dropoff_datetime is replaced by drop_off_time
# 3. passenger_count is the same
# 4. trip_distance is the same
# 5. payment_type is the same
# 6. total_amount is the same
# 7. tip_amount is the same

# %%
#--- Read the 2010 Yellow Taxi dataset then look fer the first 5 rows ---
yellow_2010 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2010\yellow_taxi_2010\yellow_tripdata_2010-01.parquet")
yellow_2010.head()
# Out:
# shape: (5, 18)
# ┌───────────┬────────────┬───────────┬───────────┬───┬─────────┬───────────┬───────────┬───────────┐
# │ vendor_id ┆ pickup_dat ┆ dropoff_d ┆ passenger ┆ … ┆ mta_tax ┆ tip_amoun ┆ tolls_amo ┆ total_amo │
# │ ---       ┆ etime      ┆ atetime   ┆ _count    ┆   ┆ ---     ┆ t         ┆ unt       ┆ unt       │
# │ str       ┆ ---        ┆ ---       ┆ ---       ┆   ┆ f64     ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str        ┆ str       ┆ i64       ┆   ┆         ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪════════════╪═══════════╪═══════════╪═══╪═════════╪═══════════╪═══════════╪═══════════╡
# │ VTS       ┆ 2010-01-26 ┆ 2010-01-2 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 5.0       │
# │           ┆ 07:41:00   ┆ 6         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 07:45:00  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ DDS       ┆ 2010-01-30 ┆ 2010-01-3 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 16.3      │
# │           ┆ 23:31:00   ┆ 0         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 23:46:12  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ DDS       ┆ 2010-01-18 ┆ 2010-01-1 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 12.7      │
# │           ┆ 20:22:20   ┆ 8         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 20:38:12  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ VTS       ┆ 2010-01-09 ┆ 2010-01-0 ┆ 2         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 14.3      │
# │           ┆ 01:18:00   ┆ 9         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 01:35:00  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ CMT       ┆ 2010-01-18 ┆ 2010-01-1 ┆ 1         ┆ … ┆ 0.5     ┆ 0.87      ┆ 0.0       ┆ 6.67      │
# │           ┆ 19:10:14   ┆ 8         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 19:17:07  ┆           ┆   ┆         ┆           ┆           ┆           │
# └───────────┴────────────┴───────────┴───────────┴───┴─────────┴───────────┴───────────┴───────────┘

# %%
#--- Find out all the columns name ---
yellow_2010.columns
# Out:
# ['vendor_id',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'pickup_longitude',
#  'pickup_latitude',
#  'rate_code',
#  'store_and_fwd_flag',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'payment_type',
#  'fare_amount',
#  'surcharge',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'total_amount']

# %% [markdown]
# ### 1.3 Yellow Taxi Data from 2011 until 2023
# The column name will be changed as follow:
# 1. tpep_pickup_datetime is replaced by pick_up_time
# 2. tpep_dropoff_datetime is replaced by drop_off_time
# 3. passenger_count is the same
# 4. trip_distance is the same
# 5. payment_type is the same
# 6. total_amount is the same
# 7. tip_amount is the same

# %%
#--- Read the 2011-2023 Yellow Taxi dataset then look fer the first 5 rows ---
yellow_2011_2023 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2022\yellow_taxi\yellow_tripdata_2022-01.parquet")
yellow_2011_2023.head()
# Out:
# shape: (5, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 2.0       ┆ … ┆ 0.3       ┆ 21.95     ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:35:40  ┆ 00:53:29  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 13.3      ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:33:43  ┆ 00:42:07  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 10.56     ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:53:21  ┆ 01:02:19  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 11.8      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:25:21  ┆ 00:35:23  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 30.3      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:36:48  ┆ 01:14:20  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
#--- Find out all the columns name ---
yellow_2011_2023.columns
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'airport_fee']

# %% [markdown]
# ## 1.4 Find the Number of Daily Trip from Yellow Taxi
# The command COUNT() will be used to find out the number of daily trip.

# %%
query_count = """
WITH CTE_2009 AS (
    SELECT 
        Trip_Pickup_DateTime AS pick_up_time,
        Trip_Dropoff_DateTime AS drop_off_time,
        Passenger_Count AS passenger_count,
        Trip_Distance AS trip_distance,
        Payment_Type AS payment_type,
        Total_Amt AS total_amount,
        Tip_Amt AS tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2009/yellow_taxi_2009/yellow_tripdata_*.parquet'
    WHERE Trip_Pickup_DateTime IS NOT NULL
        AND Trip_Dropoff_DateTime IS NOT NULL
        AND Passenger_Count IS NOT NULL
        AND Trip_Distance IS NOT NULL
        AND Payment_Type IS NOT NULL
        AND Total_Amt IS NOT NULL
        AND Tip_Amt IS NOT NULL
        AND Trip_Pickup_DateTime >= '2009-01-01' 
        AND Trip_Pickup_DateTime < '2010-10-01'
), CTE_2010 AS (
    SELECT 
        pickup_datetime AS pick_up_time,
        dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2010/yellow_taxi_2010/yellow_tripdata_*.parquet'
    WHERE pickup_datetime IS NOT NULL
        AND dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
        AND pickup_datetime >= '2010-01-01' 
        AND pickup_datetime < '2011-01-01'
), CTE_2011_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/*/yellow_taxi/yellow_tripdata_*.parquet'
    WHERE tpep_pickup_datetime IS NOT NULL
        AND tpep_dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
        AND tpep_pickup_datetime >= '2011-01-01' 
        AND tpep_dropoff_datetime < '2023-10-01'
), CTE_union_2009_2023 AS (
    SELECT * FROM CTE_2009
    UNION ALL
    SELECT * FROM CTE_2010
    UNION ALL
    SELECT * FROM CTE_2011_2023
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_union_2009_2023
)

SELECT 
    pick_up_date AS day_of_trip,
    COUNT(*) AS total_trip
FROM CTE_count_trip
GROUP BY pick_up_date
ORDER BY pick_up_date 
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#   day_of_trip  total_trip
# 0  2009-01-01      327625
# 1  2009-01-02      376708
# 2  2009-01-03      432710
# 3  2009-01-04      367525
# 4  2009-01-05      370901

# %%
#--- Check the 10 last data
df.tail(10)
# Out:
#      day_of_trip  total_trip
# 5376  2023-09-21       37282
# 5377  2023-09-22          20
# 5378  2023-09-23          18
# 5379  2023-09-24         125
# 5380  2023-09-25       87644
# 5381  2023-09-26      107736
# 5382  2023-09-27      114350
# 5383  2023-09-28      121502
# 5384  2023-09-29       95916
# 5385  2023-09-30      106804

# %%
# Plotting
# Ensure date is datetime
import pandas as pd 
df["day_of_trip"] = pd.to_datetime(df["day_of_trip"])

# Plot
plt.figure(figsize=(10,5))
plt.plot(df["day_of_trip"], df["total_trip"], marker="o", linestyle="-", label="total trips")

plt.title("The Number of New York Yellow Taxi Daily Trips")
plt.xlabel("day of trip")
plt.ylabel("total trips")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The trend is decreasing. The biggest drop was during the covid pandemic. The daily data is too dense. Let make it to be monthly data to compare with other taxi provider.

# %% [markdown]
# ## 2. Green Taxi

# %%
yellow_2009 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2009\yellow_taxi_2009\yellow_tripdata_2009-01.parquet")
yellow_2009.head()
# Out:
# shape: (5, 18)
# ┌────────────┬────────────┬────────────┬───────────┬───┬─────────┬─────────┬───────────┬───────────┐
# │ vendor_nam ┆ Trip_Picku ┆ Trip_Dropo ┆ Passenger ┆ … ┆ mta_tax ┆ Tip_Amt ┆ Tolls_Amt ┆ Total_Amt │
# │ e          ┆ p_DateTime ┆ ff_DateTim ┆ _Count    ┆   ┆ ---     ┆ ---     ┆ ---       ┆ ---       │
# │ ---        ┆ ---        ┆ e          ┆ ---       ┆   ┆ f64     ┆ f64     ┆ f64       ┆ f64       │
# │ str        ┆ str        ┆ ---        ┆ i64       ┆   ┆         ┆         ┆           ┆           │
# │            ┆            ┆ str        ┆           ┆   ┆         ┆         ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═════════╪═════════╪═══════════╪═══════════╡
# │ VTS        ┆ 2009-01-04 ┆ 2009-01-04 ┆ 1         ┆ … ┆ null    ┆ 0.0     ┆ 0.0       ┆ 9.4       │
# │            ┆ 02:52:00   ┆ 03:02:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ VTS        ┆ 2009-01-04 ┆ 2009-01-04 ┆ 3         ┆ … ┆ null    ┆ 2.0     ┆ 0.0       ┆ 14.6      │
# │            ┆ 03:31:00   ┆ 03:38:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ VTS        ┆ 2009-01-03 ┆ 2009-01-03 ┆ 5         ┆ … ┆ null    ┆ 4.74    ┆ 0.0       ┆ 28.44     │
# │            ┆ 15:43:00   ┆ 15:57:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ DDS        ┆ 2009-01-01 ┆ 2009-01-01 ┆ 1         ┆ … ┆ null    ┆ 3.05    ┆ 0.0       ┆ 18.45     │
# │            ┆ 20:52:58   ┆ 21:14:00   ┆           ┆   ┆         ┆         ┆           ┆           │
# │ DDS        ┆ 2009-01-24 ┆ 2009-01-24 ┆ 1         ┆ … ┆ null    ┆ 0.0     ┆ 0.0       ┆ 3.7       │
# │            ┆ 16:18:23   ┆ 16:24:56   ┆           ┆   ┆         ┆         ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴─────────┴─────────┴───────────┴───────────┘

# %%
yellow_2009.columns
# Out:
# ['vendor_name',
#  'Trip_Pickup_DateTime',
#  'Trip_Dropoff_DateTime',
#  'Passenger_Count',
#  'Trip_Distance',
#  'Start_Lon',
#  'Start_Lat',
#  'Rate_Code',
#  'store_and_forward',
#  'End_Lon',
#  'End_Lat',
#  'Payment_Type',
#  'Fare_Amt',
#  'surcharge',
#  'mta_tax',
#  'Tip_Amt',
#  'Tolls_Amt',
#  'Total_Amt']

# %%
query_count = """
WITH CTE_2009 AS (
    SELECT 
        Trip_Pickup_DateTime AS pick_up_time,
        Trip_Dropoff_DateTime AS drop_off_time,
        Passenger_Count AS passenger_count,
        Trip_Distance AS trip_distance,
        Payment_Type AS payment_type,
        Total_Amt AS total_amount,
        Tip_Amt AS tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2009/yellow_taxi_2009/yellow_tripdata_*.parquet'
    WHERE Trip_Pickup_DateTime IS NOT NULL
        AND Trip_Dropoff_DateTime IS NOT NULL
        AND Passenger_Count IS NOT NULL
        AND Trip_Distance IS NOT NULL
        AND Payment_Type IS NOT NULL
        AND Total_Amt IS NOT NULL
        AND Tip_Amt IS NOT NULL
        AND Trip_Pickup_DateTime >= '2009-01-01' 
        AND Trip_Pickup_DateTime < '2010-10-01'
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2009
)

SELECT 
    pick_up_date,
    COUNT(*)
FROM CTE_count_trip
GROUP BY pick_up_date
ORDER BY pick_up_date 
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#   pick_up_date  count_star()
# 0   2009-01-01        327625
# 1   2009-01-02        376708
# 2   2009-01-03        432710
# 3   2009-01-04        367525
# 4   2009-01-05        370901

# %%
df.tail(10)
# Out:
#     pick_up_date  count_star()
# 355   2009-12-22        455090
# 356   2009-12-23        456094
# 357   2009-12-24        382635
# 358   2009-12-25        233221
# 359   2009-12-26        320616
# 360   2009-12-27        312947
# 361   2009-12-28        375455
# 362   2009-12-29        447016
# 363   2009-12-30        429635
# 364   2009-12-31        461201

# %%
query_count = """
WITH CTE_2009 AS (
    SELECT 
        Trip_Pickup_DateTime AS pick_up_time,
        Trip_Dropoff_DateTime AS drop_off_time,
        Passenger_Count AS passenger_count,
        Trip_Distance AS trip_distance,
        Payment_Type AS payment_type,
        Total_Amt AS total_amount,
        Tip_Amt AS tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2009/yellow_taxi_2009/yellow_tripdata_*.parquet'
    WHERE Trip_Pickup_DateTime IS NOT NULL
        AND Trip_Dropoff_DateTime IS NOT NULL
        AND Passenger_Count IS NOT NULL
        AND Trip_Distance IS NOT NULL
        AND Payment_Type IS NOT NULL
        AND Total_Amt IS NOT NULL
        AND Tip_Amt IS NOT NULL
        AND Trip_Pickup_DateTime >= '2009-01-01' 
        AND Trip_Pickup_DateTime < '2010-01-01'
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2009
)

SELECT 
    COUNT(*)
FROM CTE_count_trip
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#    count_star()
# 0     170896055

# %%
yellow_2010 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2010\yellow_taxi_2010\yellow_tripdata_2010-01.parquet")
yellow_2010.head()
# Out:
# shape: (5, 18)
# ┌───────────┬────────────┬───────────┬───────────┬───┬─────────┬───────────┬───────────┬───────────┐
# │ vendor_id ┆ pickup_dat ┆ dropoff_d ┆ passenger ┆ … ┆ mta_tax ┆ tip_amoun ┆ tolls_amo ┆ total_amo │
# │ ---       ┆ etime      ┆ atetime   ┆ _count    ┆   ┆ ---     ┆ t         ┆ unt       ┆ unt       │
# │ str       ┆ ---        ┆ ---       ┆ ---       ┆   ┆ f64     ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str        ┆ str       ┆ i64       ┆   ┆         ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪════════════╪═══════════╪═══════════╪═══╪═════════╪═══════════╪═══════════╪═══════════╡
# │ VTS       ┆ 2010-01-26 ┆ 2010-01-2 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 5.0       │
# │           ┆ 07:41:00   ┆ 6         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 07:45:00  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ DDS       ┆ 2010-01-30 ┆ 2010-01-3 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 16.3      │
# │           ┆ 23:31:00   ┆ 0         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 23:46:12  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ DDS       ┆ 2010-01-18 ┆ 2010-01-1 ┆ 1         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 12.7      │
# │           ┆ 20:22:20   ┆ 8         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 20:38:12  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ VTS       ┆ 2010-01-09 ┆ 2010-01-0 ┆ 2         ┆ … ┆ 0.5     ┆ 0.0       ┆ 0.0       ┆ 14.3      │
# │           ┆ 01:18:00   ┆ 9         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 01:35:00  ┆           ┆   ┆         ┆           ┆           ┆           │
# │ CMT       ┆ 2010-01-18 ┆ 2010-01-1 ┆ 1         ┆ … ┆ 0.5     ┆ 0.87      ┆ 0.0       ┆ 6.67      │
# │           ┆ 19:10:14   ┆ 8         ┆           ┆   ┆         ┆           ┆           ┆           │
# │           ┆            ┆ 19:17:07  ┆           ┆   ┆         ┆           ┆           ┆           │
# └───────────┴────────────┴───────────┴───────────┴───┴─────────┴───────────┴───────────┴───────────┘

# %%
yellow_2010.columns
# Out:
# ['vendor_id',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'pickup_longitude',
#  'pickup_latitude',
#  'rate_code',
#  'store_and_fwd_flag',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'payment_type',
#  'fare_amount',
#  'surcharge',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'total_amount']

# %%
query_count = """
WITH CTE_2010 AS (
    SELECT 
        pickup_datetime AS pick_up_time,
        dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2010/yellow_taxi_2010/yellow_tripdata_*.parquet'
    WHERE pickup_datetime IS NOT NULL
        AND dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
        AND pickup_datetime >= '2010-01-01' 
        AND pickup_datetime < '2011-01-01'
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2010
)

SELECT 
    pick_up_date,
    COUNT(*)
FROM CTE_count_trip
GROUP BY pick_up_date
ORDER BY pick_up_date 
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#   pick_up_date  count_star()
# 0   2010-01-01        401856
# 1   2010-01-02        410622
# 2   2010-01-03        389569
# 3   2010-01-04        399321
# 4   2010-01-05        445264

# %%
df.tail(10)
# Out:
#     pick_up_date  count_star()
# 355   2010-12-22        485123
# 356   2010-12-23        459871
# 357   2010-12-24        361296
# 358   2010-12-25        226051
# 359   2010-12-26        193529
# 360   2010-12-27         72025
# 361   2010-12-28        247546
# 362   2010-12-29        332715
# 363   2010-12-30        372902
# 364   2010-12-31        430727

# %%
query_count = """
WITH CTE_2010 AS (
    SELECT 
        pickup_datetime AS pick_up_time,
        dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2010/yellow_taxi_2010/yellow_tripdata_*.parquet'
    WHERE pickup_datetime IS NOT NULL
        AND dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
        AND pickup_datetime >= '2010-01-01' 
        AND pickup_datetime < '2011-01-01'
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2010
)

SELECT 
    COUNT(*)
FROM CTE_count_trip
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#    count_star()
# 0     169001153

# %%
yellow_2023 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2022\yellow_taxi\yellow_tripdata_2022-01.parquet")
yellow_2023.head()
# Out:
# shape: (5, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 2.0       ┆ … ┆ 0.3       ┆ 21.95     ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:35:40  ┆ 00:53:29  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 13.3      ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:33:43  ┆ 00:42:07  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 10.56     ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:53:21  ┆ 01:02:19  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 11.8      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:25:21  ┆ 00:35:23  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2022-01-0 ┆ 2022-01-0 ┆ 1.0       ┆ … ┆ 0.3       ┆ 30.3      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:36:48  ┆ 01:14:20  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
query = """
WITH CTE_jan_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2023/yellow_taxi/yellow_tripdata_2023-01.parquet'
)

SELECT 
    *
FROM CTE_jan_2023
"""

con = duckdb.connect()
df = con.execute(query).fetchdf()
df.head()
# Out:
#          pick_up_time       drop_off_time  passenger_count  trip_distance  \
# 0 2023-01-01 00:32:10 2023-01-01 00:40:36              1.0           0.97
# 1 2023-01-01 00:55:08 2023-01-01 01:01:27              1.0           1.10
# 2 2023-01-01 00:25:04 2023-01-01 00:37:49              1.0           2.51
# 3 2023-01-01 00:03:48 2023-01-01 00:13:25              0.0           1.90
# 4 2023-01-01 00:10:29 2023-01-01 00:21:19              1.0           1.43
#
#    payment_type  total_amount  tip_amount
# 0             2         14.30        0.00
# 1             1         16.90        4.00
# 2             1         34.90       15.00
# 3             1         20.85        0.00
# 4             1         19.68        3.28

# %%
query_count = """
WITH CTE_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2023/yellow_taxi/yellow_tripdata_*.parquet'
    WHERE tpep_pickup_datetime IS NOT NULL
        AND tpep_dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2023
)

SELECT 
    pick_up_date,
    COUNT(*)
FROM CTE_count_trip
WHERE pick_up_date >= '2009-01-01' AND pick_up_date < '2023-10-01'
GROUP BY pick_up_date
ORDER BY pick_up_date DESC
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#   pick_up_date  count_star()
# 0   2023-09-30        108446
# 1   2023-09-29         95916
# 2   2023-09-28        121503
# 3   2023-09-27        114350
# 4   2023-09-26        107736

# %%
df.head(50)
# Out:
#    pick_up_date  count_star()
# 0    2023-09-30        108446
# 1    2023-09-29         95916
# 2    2023-09-28        121503
# 3    2023-09-27        114350
# 4    2023-09-26        107736
# 5    2023-09-25         87644
# 6    2023-09-24           125
# 7    2023-09-23            18
# 8    2023-09-22            20
# 9    2023-09-21         37282
# 10   2023-09-20        104203
# 11   2023-09-19        100220
# 12   2023-09-18         91317
# 13   2023-09-17         89455
# 14   2023-09-16        106004
# 15   2023-09-15        111937
# 16   2023-09-14        120918
# 17   2023-09-13        114452
# 18   2023-09-12        114358
# 19   2023-09-11        102602
# 20   2023-09-10         98819
# 21   2023-09-09        112074
# 22   2023-09-08        118872
# 23   2023-09-07        124672
# 24   2023-09-06        114028
# 25   2023-09-05         99637
# 26   2023-09-04         69628
# 27   2023-09-03         75978
# 28   2023-09-02         79976
# 29   2023-09-01         84290
# 30   2023-08-31         88556
# 31   2023-08-30         89517
# 32   2023-08-29         91314
# 33   2023-08-28         76220
# 34   2023-08-27         78205
# 35   2023-08-26         87758
# 36   2023-08-25         86367
# 37   2023-08-24         92572
# 38   2023-08-23         89831
# 39   2023-08-22         84554
# 40   2023-08-21         77676
# 41   2023-08-20         75288
# 42   2023-08-19         86711
# 43   2023-08-18         87110
# 44   2023-08-17         97296
# 45   2023-08-16         96950
# 46   2023-08-15         90854
# 47   2023-08-14         81376
# 48   2023-08-13         77061
# 49   2023-08-12         87146

# %%
query_count = """
WITH CTE_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2009/yellow_taxi_*/yellow_tripdata_*.parquet'
    WHERE tpep_pickup_datetime IS NOT NULL
        AND tpep_dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2023
)

SELECT 
    COUNT(*)
FROM CTE_count_trip
WHERE pick_up_date >= '2009-01-01' AND pick_up_date < '2023-10-01'
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()

# %%
query_count = """
WITH CTE_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/*/yellow_taxi/yellow_tripdata_*.parquet'
    WHERE tpep_pickup_datetime IS NOT NULL
        AND tpep_dropoff_datetime IS NOT NULL
        AND passenger_count IS NOT NULL
        AND trip_distance IS NOT NULL
        AND payment_type IS NOT NULL
        AND total_amount IS NOT NULL
        AND tip_amount IS NOT NULL
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_2023
)

SELECT 
    COUNT(*)
FROM CTE_count_trip
WHERE pick_up_date >= '2009-01-01' AND pick_up_date < '2023-10-01'
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#    count_star()
# 0    1381927977
