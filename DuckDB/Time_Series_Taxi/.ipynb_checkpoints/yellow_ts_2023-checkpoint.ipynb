# %%
import polars as pl
import duckdb

# %%
yellow_2023 = pl.read_parquet(r"C:\Users\ekadw\Documents\DATA\NY_Taxi\2023\yellow_taxi\yellow_tripdata_2023-01.parquet")
yellow_2023.head()
# Out:
# shape: (5, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i64      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 1.0       ┆ … ┆ 1.0       ┆ 14.3      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:32:10  ┆ 00:40:36  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 1.0       ┆ … ┆ 1.0       ┆ 16.9      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:55:08  ┆ 01:01:27  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 1.0       ┆ … ┆ 1.0       ┆ 34.9      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:25:04  ┆ 00:37:49  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 0.0       ┆ … ┆ 1.0       ┆ 20.85     ┆ 0.0       ┆ 1.25      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:03:48  ┆ 00:13:25  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2023-01-0 ┆ 2023-01-0 ┆ 1.0       ┆ … ┆ 1.0       ┆ 19.68     ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:10:29  ┆ 00:21:19  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
query = """
WITH CTE_jan_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2023/yellow_taxi/yellow_tripdata_2023-01.parquet'
)

SELECT 
    *
FROM CTE_jan_2023
"""

con = duckdb.connect()
df = con.execute(query).fetchdf()
df.head()
# Out:
#          pick_up_time       drop_off_time  passenger_count  trip_distance  \
# 0 2023-01-01 00:32:10 2023-01-01 00:40:36              1.0           0.97
# 1 2023-01-01 00:55:08 2023-01-01 01:01:27              1.0           1.10
# 2 2023-01-01 00:25:04 2023-01-01 00:37:49              1.0           2.51
# 3 2023-01-01 00:03:48 2023-01-01 00:13:25              0.0           1.90
# 4 2023-01-01 00:10:29 2023-01-01 00:21:19              1.0           1.43
#
#    payment_type  total_amount  tip_amount
# 0             2         14.30        0.00
# 1             1         16.90        4.00
# 2             1         34.90       15.00
# 3             1         20.85        0.00
# 4             1         19.68        3.28

# %%
query_count = """
WITH CTE_jan_2023 AS (
    SELECT 
        tpep_pickup_datetime AS pick_up_time,
        tpep_dropoff_datetime AS drop_off_time,
        passenger_count,
        trip_distance,
        payment_type,
        total_amount,
        tip_amount
    FROM 'C:/Users/ekadw/Documents/DATA/NY_Taxi/2023/yellow_taxi/yellow_tripdata_2023-01.parquet'
), CTE_count_trip AS (
    SELECT
        DATE(pick_up_time) AS pick_up_date
    FROM CTE_jan_2023
)

SELECT 
    pick_up_date,
    COUNT(*)
FROM CTE_count_trip
GROUP BY pick_up_date
ORDER BY pick_up_date DESC
"""

con = duckdb.connect()
df = con.execute(query_count).fetchdf()
df.head()
# Out:
#   pick_up_date  count_star()
# 0   2023-02-01            10
# 1   2023-01-31        100372
# 2   2023-01-30         83768
# 3   2023-01-29         88131
# 4   2023-01-28        111645

# %%
df
# Out:
#    pick_up_date  count_star()
# 0    2023-02-01            10
# 1    2023-01-31        100372
# 2    2023-01-30         83768
# 3    2023-01-29         88131
# 4    2023-01-28        111645
# 5    2023-01-27        111668
# 6    2023-01-26        114877
# 7    2023-01-25        109196
# 8    2023-01-24        103858
# 9    2023-01-23         89791
# 10   2023-01-22         89651
# 11   2023-01-21        111999
# 12   2023-01-20        109444
# 13   2023-01-19        114603
# 14   2023-01-18        106152
# 15   2023-01-17        101052
# 16   2023-01-16         80120
# 17   2023-01-15         96844
# 18   2023-01-14        112950
# 19   2023-01-13        110719
# 20   2023-01-12        111386
# 21   2023-01-11        106118
# 22   2023-01-10         99916
# 23   2023-01-09         85349
# 24   2023-01-08         85056
# 25   2023-01-07        105036
# 26   2023-01-06        102550
# 27   2023-01-05        101063
# 28   2023-01-04         95092
# 29   2023-01-03         85783
# 30   2023-01-02         65777
# 31   2023-01-01         76752
# 32   2022-12-31            25
# 33   2022-10-25             7
# 34   2022-10-24             4
# 35   2008-12-31             2
